# %%
import math
import numpy as np
import h5py
import matplotlib.pyplot as plt
from matplotlib.pyplot import imread
import scipy
from PIL import Image
import pandas as pd
import tensorflow as tf
import tensorflow.keras.layers as tfl
from tensorflow.python.framework import ops
from cnn_utils import *
from test_utils import summary, comparator

# %matplotlib inline
np.random.seed(1)
# Out:
# 2024-10-24 13:36:05.368847: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-24 13:36:05.384549: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-24 13:36:05.389304: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
def load_inferno_dataset():
    train_dataset = h5py.File('datasets/train_inferno.h5', "r")
    train_set_x_orig = np.array(train_dataset["train_set_x"][:]) # your train set features
    train_set_y_orig = np.array(train_dataset["train_set_y"][:]) # your train set labels

    test_dataset = h5py.File('datasets/test_inferno.h5', "r")
    test_set_x_orig = np.array(test_dataset["test_set_x"][:]) # your test set features
    test_set_y_orig = np.array(test_dataset["test_set_y"][:]) # your test set labels

    classes = np.array(test_dataset["list_classes"][:]) # the list of classes
    
    train_set_y_orig = train_set_y_orig.reshape((1, train_set_y_orig.shape[0]))
    test_set_y_orig = test_set_y_orig.reshape((1, test_set_y_orig.shape[0]))
    
    return train_set_x_orig, train_set_y_orig, test_set_x_orig, test_set_y_orig, classes



# Loading the data 
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig, classes = load_inferno_dataset()


# Normalize image vectors
X_train = X_train_orig/255.
X_test = X_test_orig/255.


Y_train = convert_to_one_hot(Y_train_orig, 10).T
Y_test = convert_to_one_hot(Y_test_orig, 10).T
print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 9000
# number of test examples = 1000
# X_train shape: (9000, 48, 48, 3)
# Y_train shape: (9000, 10)
# X_test shape: (1000, 48, 48, 3)
# Y_test shape: (1000, 10)

# %%
index = 124
plt.imshow(X_train_orig[index]) #display sample training image
plt.show()

# %%
def convolutional_model(input_shape):
    """
    Implements the forward propagation for the model:
    CONV2D -> RELU -> MAXPOOL -> CONV2D -> RELU -> MAXPOOL -> FLATTEN -> DENSE
    
    Note that for simplicity and grading purposes, you'll hard-code some values
    such as the stride and kernel (filter) sizes. 
    Normally, functions should take these values as function parameters.
    
    Arguments:
    input_img -- input dataset, of shape (input_shape)

    Returns:
    model -- TF Keras model (object containing the information for the entire training process) 
    """
    # YOUR CODE STARTS HERE

    input_img = tf.keras.Input(shape=input_shape)
    
    ## CONV2D: 8 filters 4x4, stride of 1, padding 'SAME'
    Z1 = tf.keras.layers.Conv2D(filters=8, kernel_size=4, strides=1, padding='same')(input_img)
    
    ## RELU
    A1 = tf.keras.layers.ReLU()(Z1)
    
    ## MAXPOOL: window 8x8, stride 8, padding 'SAME'
    P1 = tf.keras.layers.MaxPool2D(pool_size=(8, 8), strides=(8, 8), padding='same')(A1)
    
    ## CONV2D: 16 filters 2x2, stride 1, padding 'SAME'
    Z2 = tf.keras.layers.Conv2D(filters=16, kernel_size=2, strides=1, padding='same')(P1)
    
    ## RELU
    A2 = tf.keras.layers.ReLU()(Z2)
    
    ## MAXPOOL: window 4x4, stride 4, padding 'SAME'
    P2 = tf.keras.layers.MaxPool2D(pool_size=(4, 4), strides=(4, 4), padding='same')(A2)
    
    ## FLATTEN
    F  = tf.keras.layers.Flatten()(P2)
    
    ## Dense layer
    ## 6 neurons in output layer. Hint: one of the arguments should be "activation='softmax'" 
    outputs = tf.keras.layers.Dense(units= 10, activation='softmax')(F)
    
    # YOUR CODE ENDS HERE
    model = tf.keras.Model(inputs=input_img, outputs=outputs)
    return model

# %%
conv_model = convolutional_model((48, 48, 3))
conv_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
conv_model.summary()

# X_train = X_train[:900]
# Y_train = Y_train[:900]
# X_test = X_test[:100]
# Y_test = Y_test[:100]
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1729769780.043266  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.043647  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.043959  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.044265  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.085013  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.085416  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.085735  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.086047  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.086352  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.086655  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.086953  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.087250  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.443364  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.443718  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.444029  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.444332  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.444639  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.444936  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.445228  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.445521  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.445818  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.446111  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.446403  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.446700  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.466264  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.466641  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.466998  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.467378  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.467694  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.467997  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.468293  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.468593  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1729769780.468902  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-24 13:36:20.469183: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22272 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:02:00.0, compute capability: 8.9
# I0000 00:00:1729769780.469539  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-24 13:36:20.469824: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 21210 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:21:00.0, compute capability: 8.9
# I0000 00:00:1729769780.470116  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-24 13:36:20.470387: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 22272 MB memory:  -> device: 2, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:4d:00.0, compute capability: 8.9
# I0000 00:00:1729769780.470676  138509 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-24 13:36:20.470949: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 22272 MB memory:  -> device: 3, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:4e:00.0, compute capability: 8.9
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 48, 48, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 48, 48, 8)      │           392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 48, 48, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 6, 6, 8)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 6, 6, 16)       │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_1 (ReLU)                  │ (None, 6, 6, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 2, 2, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,570 (6.13 KB)
#  Trainable params: 1,570 (6.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, Y_train)).batch(64)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, Y_test)).batch(64)
history = conv_model.fit(train_dataset, epochs=10, validation_data=test_dataset)
# Out:
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1729769812.213736  138778 service.cc:146] XLA service 0x723d8000a500 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1729769812.213775  138778 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# I0000 00:00:1729769812.213779  138778 service.cc:154]   StreamExecutor device (1): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# I0000 00:00:1729769812.213782  138778 service.cc:154]   StreamExecutor device (2): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# I0000 00:00:1729769812.213786  138778 service.cc:154]   StreamExecutor device (3): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2024-10-24 13:36:52.249688: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-10-24 13:36:52.571472: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90400
#  50/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0894 - loss: 2.3129
# I0000 00:00:1729769813.743099  138778 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.2087 - loss: 2.1758 - val_accuracy: 0.7690 - val_loss: 1.2175
# Epoch 2/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8719 - loss: 0.8871 - val_accuracy: 0.9880 - val_loss: 0.2553
# Epoch 3/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9869 - loss: 0.2060 - val_accuracy: 0.9910 - val_loss: 0.0874
# Epoch 4/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9916 - loss: 0.0779 - val_accuracy: 0.9940 - val_loss: 0.0500
# Epoch 5/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9951 - loss: 0.0465 - val_accuracy: 0.9950 - val_loss: 0.0387
# Epoch 6/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9964 - loss: 0.0341 - val_accuracy: 0.9950 - val_loss: 0.0333
# Epoch 7/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9967 - loss: 0.0278 - val_accuracy: 0.9950 - val_loss: 0.0307
# Epoch 8/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9971 - loss: 0.0238 - val_accuracy: 0.9960 - val_loss: 0.0285
# Epoch 9/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9971 - loss: 0.0208 - val_accuracy: 0.9960 - val_loss: 0.0269
# Epoch 10/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9975 - loss: 0.0185 - val_accuracy: 0.9960 - val_loss: 0.0262

# %%
history.history
# Out:
# {'accuracy': [0.39144444465637207,
#   0.9245555400848389,
#   0.9864444732666016,
#   0.991777777671814,
#   0.9948889017105103,
#   0.9956666827201843,
#   0.9959999918937683,
#   0.9963333606719971,
#   0.9965555667877197,
#   0.9967777729034424],
#  'loss': [1.926016926765442,
#   0.6373363137245178,
#   0.1635178178548813,
#   0.07245736569166183,
#   0.048260148614645004,
#   0.03800514340400696,
#   0.03251868486404419,
#   0.028969472274184227,
#   0.026266589760780334,
#   0.024179738014936447],
#  'val_accuracy': [0.7689999938011169,
#   0.9879999756813049,
#   0.9909999966621399,
#   0.9940000176429749,
#   0.9950000047683716,
#   0.9950000047683716,
#   0.9950000047683716,
#   0.9959999918937683,
#   0.9959999918937683,
#   0.9959999918937683],
#  'val_loss': [1.2174731492996216,
#   0.2553110420703888,
#   0.08740751445293427,
#   0.049981605261564255,
#   0.03866548091173172,
#   0.03332962840795517,
#   0.030689196661114693,
#   0.028472092002630234,
#   0.026878997683525085,
#   0.026217089965939522]}

# %%
# The history.history["loss"] entry is a dictionary with as many values as epochs that the
# model was trained on. 
df_loss_acc = pd.DataFrame(history.history)
df_loss= df_loss_acc[['loss','val_loss']]
df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)
df_acc= df_loss_acc[['accuracy','val_accuracy']]
df_acc.rename(columns={'accuracy':'train','val_accuracy':'validation'},inplace=True)
df_loss.plot(title='Model loss',figsize=(12,8)).set(xlabel='Epoch',ylabel='Loss')
df_acc.plot(title='Model Accuracy',figsize=(12,8)).set(xlabel='Epoch',ylabel='Accuracy')
# Out:
# /usr/lib/python3/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# [Text(0.5, 0, 'Epoch'), Text(0, 0.5, 'Accuracy')]

# %%
# Save the model
conv_model.save('inferno_model.keras')

# %% [markdown]
# <a name='4-1'></a>
# ### - Load the Model to test with some images

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import os
import random

# Load the model
model = tf.keras.models.load_model('inferno_model.keras')

# Function to load and preprocess an image
def load_and_preprocess_image(img_path):
    img = image.load_img(img_path, target_size=(48, 48))  # Change target size as per your model's input
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    img_array = img_array / 255.0  # Normalize to [0, 1]
    return img_array
# Out:
# C:\Users\Roberto Brusnicki\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 8 variables whereas the saved optimizer has 14 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
# Create a figure for the grid
fig, axs = plt.subplots(5, 2, figsize=(4, 6))  # 5 rows, 2 columns

# List of directories to sample images from
directories = [
    'datasets/inferno/bomb',
    'datasets/inferno/decoy',
    'datasets/inferno/flash',
    'datasets/inferno/flash2',
    'datasets/inferno/he',
    'datasets/inferno/incendiary',
    'datasets/inferno/kit',
    'datasets/inferno/molotov',
    'datasets/inferno/none',
    'datasets/inferno/smoke'
]

# Loop to test 10 different images
for i in range(10):
    # Randomly select a directory
    selected_dir = directories[i]
    
    # Get a list of images in the selected directory
    image_files = os.listdir(selected_dir)
    
    # Randomly select an image from the directory
    selected_image = random.choice(image_files)
    
    # Construct the full path to the image
    img_path = os.path.join(selected_dir, selected_image)
    
    # Load and preprocess the image
    img_array = load_and_preprocess_image(img_path)

    # Make predictions
    predictions = model.predict(img_array)
    predicted_class = np.argmax(predictions, axis=1)

    # Display the image in the grid
    ax = axs[i // 2, i % 2]  # Calculate position in grid
    ax.imshow(image.load_img(img_path))
    ax.set_title(f'Predicted: {predicted_class[0]}')
    ax.axis('off')  # Hide axes

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %% [markdown]
# <a name='4-2'></a>
# ### 4.2 - Split the Data into Train/Test Sets
#
# In Course 2, you built a fully-connected network for this dataset. But since this is an image dataset, it is more natural to apply a ConvNet to it.
#
# To get started, let's examine the shapes of your data.

# %%
X_train = X_train_orig/255.
X_test = X_test_orig/255.
Y_train = convert_to_one_hot(Y_train_orig, 6).T
Y_test = convert_to_one_hot(Y_test_orig, 6).T
print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 1080
# number of test examples = 120
# X_train shape: (1080, 64, 64, 3)
# Y_train shape: (1080, 6)
# X_test shape: (120, 64, 64, 3)
# Y_test shape: (120, 6)

# %% [markdown]
# <a name='4-3'></a>
# ### 4.3 - Forward Propagation
#
# In TensorFlow, there are built-in functions that implement the convolution steps for you. By now, you should be familiar with how TensorFlow builds computational graphs. In the [Functional API](https://www.tensorflow.org/guide/keras/functional), you create a graph of layers. This is what allows such great flexibility.
#
# However, the following model could also be defined using the Sequential API since the information flow is on a single line. But don't deviate. What we want you to learn is to use the functional API.
#
# Begin building your graph of layers by creating an input node that functions as a callable object:
#
# - **input_img = tf.keras.Input(shape=input_shape):**
#
# Then, create a new node in the graph of layers by calling a layer on the `input_img` object:
#
# - **tf.keras.layers.Conv2D(filters= ... , kernel_size= ... , padding='same')(input_img):** Read the full documentation on [Conv2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D).
#
# - **tf.keras.layers.MaxPool2D(pool_size=(f, f), strides=(s, s), padding='same'):** `MaxPool2D()` downsamples your input using a window of size (f, f) and strides of size (s, s) to carry out max pooling over each window.  For max pooling, you usually operate on a single example at a time and a single channel at a time. Read the full documentation on [MaxPool2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D).
#
# - **tf.keras.layers.ReLU():** computes the elementwise ReLU of Z (which can be any shape). You can read the full documentation on [ReLU](https://www.tensorflow.org/api_docs/python/tf/keras/layers/ReLU).
#
# - **tf.keras.layers.Flatten()**: given a tensor "P", this function takes each training (or test) example in the batch and flattens it into a 1D vector.
#
#     * If a tensor P has the shape (batch_size,h,w,c), it returns a flattened tensor with shape (batch_size, k), where $k=h \times w \times c$.  "k" equals the product of all the dimension sizes other than the first dimension.
#
#     * For example, given a tensor with dimensions [100, 2, 3, 4], it flattens the tensor to be of shape [100, 24], where 24 = 2 * 3 * 4.  You can read the full documentation on [Flatten](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Flatten).
#
# - **tf.keras.layers.Dense(units= ... , activation='softmax')(F):** given the flattened input F, it returns the output computed using a fully connected layer. You can read the full documentation on [Dense](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense).
#
# In the last function above (`tf.keras.layers.Dense()`), the fully connected layer automatically initializes weights in the graph and keeps on training them as you train the model. Hence, you did not need to initialize those weights when initializing the parameters.
#
# Lastly, before creating the model, you'll need to define the output using the last of the function's compositions (in this example, a Dense layer):
#
# - **outputs = tf.keras.layers.Dense(units=6, activation='softmax')(F)**
#
#
# #### Window, kernel, filter, pool
#
# The words "kernel" and "filter" are used to refer to the same thing. The word "filter" accounts for the amount of "kernels" that will be used in a single convolution layer. "Pool" is the name of the operation that takes the max or average value of the kernels.
#
# This is why the parameter `pool_size` refers to `kernel_size`, and you use `(f,f)` to refer to the filter size.
#
# Pool size and kernel size refer to the same thing in different objects - They refer to the shape of the window where the operation takes place.

# %% [markdown]
# <a name='ex-2'></a>
# ### Exercise 2 - convolutional_model
#
# Implement the `convolutional_model` function below to build the following model: `CONV2D -> RELU -> MAXPOOL -> CONV2D -> RELU -> MAXPOOL -> FLATTEN -> DENSE`. Use the functions above!
#
# Also, plug in the following parameters for all the steps:
#
#  - [Conv2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D): Use 8 4 by 4 filters, stride 1, padding is "SAME"
#  - [ReLU](https://www.tensorflow.org/api_docs/python/tf/keras/layers/ReLU)
#  - [MaxPool2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D): Use an 8 by 8 filter size and an 8 by 8 stride, padding is "SAME"
#  - **Conv2D**: Use 16 2 by 2 filters, stride 1, padding is "SAME"
#  - **ReLU**
#  - **MaxPool2D**: Use a 4 by 4 filter size and a 4 by 4 stride, padding is "SAME"
#  - [Flatten](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Flatten) the previous output.
#  - Fully-connected ([Dense](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense)) layer: Apply a fully connected layer with 6 neurons and a softmax activation.

# %%
# GRADED FUNCTION: convolutional_model

def convolutional_model(input_shape):
    """
    Implements the forward propagation for the model:
    CONV2D -> RELU -> MAXPOOL -> CONV2D -> RELU -> MAXPOOL -> FLATTEN -> DENSE
    
    Note that for simplicity and grading purposes, you'll hard-code some values
    such as the stride and kernel (filter) sizes. 
    Normally, functions should take these values as function parameters.
    
    Arguments:
    input_img -- input dataset, of shape (input_shape)

    Returns:
    model -- TF Keras model (object containing the information for the entire training process) 
    """
    # YOUR CODE STARTS HERE

    input_img = tf.keras.Input(shape=input_shape)
    
    ## CONV2D: 8 filters 4x4, stride of 1, padding 'SAME'
    Z1 = tf.keras.layers.Conv2D(filters=8, kernel_size=4, strides=1, padding='same')(input_img)
    
    ## RELU
    A1 = tf.keras.layers.ReLU()(Z1)
    
    ## MAXPOOL: window 8x8, stride 8, padding 'SAME'
    P1 = tf.keras.layers.MaxPool2D(pool_size=(8, 8), strides=(8, 8), padding='same')(A1)
    
    ## CONV2D: 16 filters 2x2, stride 1, padding 'SAME'
    Z2 = tf.keras.layers.Conv2D(filters=16, kernel_size=2, strides=1, padding='same')(P1)
    
    ## RELU
    A2 = tf.keras.layers.ReLU()(Z2)
    
    ## MAXPOOL: window 4x4, stride 4, padding 'SAME'
    P2 = tf.keras.layers.MaxPool2D(pool_size=(4, 4), strides=(4, 4), padding='same')(A2)
    
    ## FLATTEN
    F  = tf.keras.layers.Flatten()(P2)
    
    ## Dense layer
    ## 6 neurons in output layer. Hint: one of the arguments should be "activation='softmax'" 
    outputs = tf.keras.layers.Dense(units= 6, activation='softmax')(F)
    
    # YOUR CODE ENDS HERE
    model = tf.keras.Model(inputs=input_img, outputs=outputs)
    return model

# %%
conv_model = convolutional_model((64, 64, 3))
conv_model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
conv_model.summary()
    
output = [['InputLayer', [(None, 64, 64, 3)], 0],
        ['Conv2D', (None, 64, 64, 8), 392, 'same', 'linear', 'GlorotUniform'],
        ['ReLU', (None, 64, 64, 8), 0],
        ['MaxPooling2D', (None, 8, 8, 8), 0, (8, 8), (8, 8), 'same'],
        ['Conv2D', (None, 8, 8, 16), 528, 'same', 'linear', 'GlorotUniform'],
        ['ReLU', (None, 8, 8, 16), 0],
        ['MaxPooling2D', (None, 2, 2, 16), 0, (4, 4), (4, 4), 'same'],
        ['Flatten', (None, 64), 0],
        ['Dense', (None, 6), 390, 'softmax']]
    
comparator(summary(conv_model), output)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 8)      │           392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_1 (ReLU)                  │ (None, 64, 64, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 8)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 8, 8, 16)       │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_2 (ReLU)                  │ (None, 8, 8, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 2, 2, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │           390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,310 (5.12 KB)
#  Trainable params: 1,310 (5.12 KB)
#  Non-trainable params: 0 (0.00 B)
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /tmp/ipykernel_72100/44648973.py in <module>
#      15         ['Dense', (None, 6), 390, 'softmax']]
#      16
# ---> 17 comparator(summary(conv_model), output)
#
# ~/Documents/Coursera/DL/CNN/W1A2/test_utils.py in summary(model)
#      65             output_shape = layer.output_shape
#      66         else:
# ---> 67             output_shape = layer.compute_output_shape(input_shape)
#      68
#      69         descriptors = [layer.__class__.__name__, output_shape, layer.count_params()]
#
# /usr/lib/python3/dist-packages/keras/src/layers/layer.py in compute_output_shape(self, *args, **kwargs)
#    1089     @utils.default
#    1090     def compute_output_shape(self, *args, **kwargs):
# -> 1091         raise NotImplementedError(
#    1092             f"Layer {self.__class__.__name__} should implement "
#    1093             "`def compute_output_shape(self, input_shape)`."
#
# NotImplementedError: Layer InputLayer should implement `def compute_output_shape(self, input_shape)`.

# %% [markdown]
# Both the Sequential and Functional APIs return a TF Keras model object. The only difference is how inputs are handled inside the object model!

# %% [markdown]
# <a name='4-4'></a>
# ### 4.4 - Train the Model

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, Y_train)).batch(64)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, Y_test)).batch(64)
history = conv_model.fit(train_dataset, epochs=300, validation_data=test_dataset)
# Out:
# Epoch 1/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - accuracy: 0.1962 - loss: 1.7930 - val_accuracy: 0.2083 - val_loss: 1.7810
# Epoch 2/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2244 - loss: 1.7809 - val_accuracy: 0.2083 - val_loss: 1.7757
# Epoch 3/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2246 - loss: 1.7738 - val_accuracy: 0.2250 - val_loss: 1.7691
# Epoch 4/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2394 - loss: 1.7661 - val_accuracy: 0.3417 - val_loss: 1.7604
# Epoch 5/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3075 - loss: 1.7564 - val_accuracy: 0.3833 - val_loss: 1.7504
# Epoch 6/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3513 - loss: 1.7451 - val_accuracy: 0.4250 - val_loss: 1.7379
# Epoch 7/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4240 - loss: 1.7316 - val_accuracy: 0.4583 - val_loss: 1.7213
# Epoch 8/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4455 - loss: 1.7141 - val_accuracy: 0.4750 - val_loss: 1.7027
# Epoch 9/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4647 - loss: 1.6932 - val_accuracy: 0.4667 - val_loss: 1.6778
# Epoch 10/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4620 - loss: 1.6663 - val_accuracy: 0.4833 - val_loss: 1.6468
# Epoch 11/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4686 - loss: 1.6333 - val_accuracy: 0.4750 - val_loss: 1.6114
# Epoch 12/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4630 - loss: 1.5958 - val_accuracy: 0.4750 - val_loss: 1.5707
# Epoch 13/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4906 - loss: 1.5507 - val_accuracy: 0.5000 - val_loss: 1.5220
# Epoch 14/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5007 - loss: 1.4995 - val_accuracy: 0.5000 - val_loss: 1.4728
# Epoch 15/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5143 - loss: 1.4448 - val_accuracy: 0.5583 - val_loss: 1.4173
# Epoch 16/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5390 - loss: 1.3823 - val_accuracy: 0.5750 - val_loss: 1.3605
# Epoch 17/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5612 - loss: 1.3181 - val_accuracy: 0.5750 - val_loss: 1.3115
# Epoch 18/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5841 - loss: 1.2606 - val_accuracy: 0.5750 - val_loss: 1.2612
# Epoch 19/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6113 - loss: 1.2066 - val_accuracy: 0.5750 - val_loss: 1.2239
# Epoch 20/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6224 - loss: 1.1607 - val_accuracy: 0.6167 - val_loss: 1.1869
# Epoch 21/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6343 - loss: 1.1189 - val_accuracy: 0.6250 - val_loss: 1.1492
# Epoch 22/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6582 - loss: 1.0825 - val_accuracy: 0.6167 - val_loss: 1.1250
# Epoch 23/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6629 - loss: 1.0521 - val_accuracy: 0.6583 - val_loss: 1.0912
# Epoch 24/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6696 - loss: 1.0202 - val_accuracy: 0.6500 - val_loss: 1.0663
# Epoch 25/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6756 - loss: 0.9945 - val_accuracy: 0.6333 - val_loss: 1.0435
# Epoch 26/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6842 - loss: 0.9686 - val_accuracy: 0.6417 - val_loss: 1.0188
# Epoch 27/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6891 - loss: 0.9452 - val_accuracy: 0.6583 - val_loss: 0.9978
# Epoch 28/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6960 - loss: 0.9237 - val_accuracy: 0.6667 - val_loss: 0.9775
# Epoch 29/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7080 - loss: 0.9029 - val_accuracy: 0.6833 - val_loss: 0.9559
# Epoch 30/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7189 - loss: 0.8828 - val_accuracy: 0.6917 - val_loss: 0.9385
# Epoch 31/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7255 - loss: 0.8652 - val_accuracy: 0.6917 - val_loss: 0.9207
# Epoch 32/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7318 - loss: 0.8479 - val_accuracy: 0.7000 - val_loss: 0.9049
# Epoch 33/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7358 - loss: 0.8317 - val_accuracy: 0.6917 - val_loss: 0.8890
# Epoch 34/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7437 - loss: 0.8162 - val_accuracy: 0.6917 - val_loss: 0.8740
# Epoch 35/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7479 - loss: 0.8008 - val_accuracy: 0.7083 - val_loss: 0.8592
# Epoch 36/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7519 - loss: 0.7867 - val_accuracy: 0.7250 - val_loss: 0.8447
# Epoch 37/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7637 - loss: 0.7726 - val_accuracy: 0.7250 - val_loss: 0.8309
# Epoch 38/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7650 - loss: 0.7590 - val_accuracy: 0.7417 - val_loss: 0.8178
# Epoch 39/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7672 - loss: 0.7457 - val_accuracy: 0.7583 - val_loss: 0.8059
# Epoch 40/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7741 - loss: 0.7328 - val_accuracy: 0.7583 - val_loss: 0.7932
# Epoch 41/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7787 - loss: 0.7199 - val_accuracy: 0.7583 - val_loss: 0.7818
# Epoch 42/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7882 - loss: 0.7069 - val_accuracy: 0.7417 - val_loss: 0.7704
# Epoch 43/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7902 - loss: 0.6940 - val_accuracy: 0.7417 - val_loss: 0.7596
# Epoch 44/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8041 - loss: 0.6814 - val_accuracy: 0.7500 - val_loss: 0.7490
# Epoch 45/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8076 - loss: 0.6697 - val_accuracy: 0.7500 - val_loss: 0.7376
# Epoch 46/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8081 - loss: 0.6576 - val_accuracy: 0.7500 - val_loss: 0.7268
# Epoch 47/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8107 - loss: 0.6462 - val_accuracy: 0.7500 - val_loss: 0.7159
# Epoch 48/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8132 - loss: 0.6349 - val_accuracy: 0.7500 - val_loss: 0.7058
# Epoch 49/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8163 - loss: 0.6245 - val_accuracy: 0.7583 - val_loss: 0.6950
# Epoch 50/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8229 - loss: 0.6140 - val_accuracy: 0.7667 - val_loss: 0.6849
# Epoch 51/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8229 - loss: 0.6034 - val_accuracy: 0.7667 - val_loss: 0.6753
# Epoch 52/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8242 - loss: 0.5933 - val_accuracy: 0.7750 - val_loss: 0.6659
# Epoch 53/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8303 - loss: 0.5838 - val_accuracy: 0.7833 - val_loss: 0.6564
# Epoch 54/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8346 - loss: 0.5740 - val_accuracy: 0.7833 - val_loss: 0.6469
# Epoch 55/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8358 - loss: 0.5648 - val_accuracy: 0.7833 - val_loss: 0.6380
# Epoch 56/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8358 - loss: 0.5559 - val_accuracy: 0.7833 - val_loss: 0.6289
# Epoch 57/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8393 - loss: 0.5471 - val_accuracy: 0.7833 - val_loss: 0.6204
# Epoch 58/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8410 - loss: 0.5385 - val_accuracy: 0.7833 - val_loss: 0.6123
# Epoch 59/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8431 - loss: 0.5302 - val_accuracy: 0.7833 - val_loss: 0.6044
# Epoch 60/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8472 - loss: 0.5222 - val_accuracy: 0.7917 - val_loss: 0.5971
# Epoch 61/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8509 - loss: 0.5145 - val_accuracy: 0.7917 - val_loss: 0.5894
# Epoch 62/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8553 - loss: 0.5069 - val_accuracy: 0.7917 - val_loss: 0.5828
# Epoch 63/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8566 - loss: 0.4995 - val_accuracy: 0.7917 - val_loss: 0.5768
# Epoch 64/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8568 - loss: 0.4924 - val_accuracy: 0.7917 - val_loss: 0.5705
# Epoch 65/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8621 - loss: 0.4855 - val_accuracy: 0.7917 - val_loss: 0.5644
# Epoch 66/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8610 - loss: 0.4785 - val_accuracy: 0.7917 - val_loss: 0.5584
# Epoch 67/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8648 - loss: 0.4718 - val_accuracy: 0.7917 - val_loss: 0.5526
# Epoch 68/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8666 - loss: 0.4653 - val_accuracy: 0.7917 - val_loss: 0.5466
# Epoch 69/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8687 - loss: 0.4589 - val_accuracy: 0.7917 - val_loss: 0.5403
# Epoch 70/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8709 - loss: 0.4527 - val_accuracy: 0.8000 - val_loss: 0.5344
# Epoch 71/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8709 - loss: 0.4465 - val_accuracy: 0.7917 - val_loss: 0.5283
# Epoch 72/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8732 - loss: 0.4402 - val_accuracy: 0.7917 - val_loss: 0.5229
# Epoch 73/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8771 - loss: 0.4345 - val_accuracy: 0.7917 - val_loss: 0.5174
# Epoch 74/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8764 - loss: 0.4287 - val_accuracy: 0.7917 - val_loss: 0.5120
# Epoch 75/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8822 - loss: 0.4230 - val_accuracy: 0.8000 - val_loss: 0.5062
# Epoch 76/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8833 - loss: 0.4174 - val_accuracy: 0.8000 - val_loss: 0.5013
# Epoch 77/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8837 - loss: 0.4122 - val_accuracy: 0.8083 - val_loss: 0.4963
# Epoch 78/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8837 - loss: 0.4071 - val_accuracy: 0.8083 - val_loss: 0.4913
# Epoch 79/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8862 - loss: 0.4019 - val_accuracy: 0.8083 - val_loss: 0.4870
# Epoch 80/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8868 - loss: 0.3972 - val_accuracy: 0.8167 - val_loss: 0.4822
# Epoch 81/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8868 - loss: 0.3926 - val_accuracy: 0.8250 - val_loss: 0.4780
# Epoch 82/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8893 - loss: 0.3880 - val_accuracy: 0.8250 - val_loss: 0.4736
# Epoch 83/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8881 - loss: 0.3836 - val_accuracy: 0.8250 - val_loss: 0.4695
# Epoch 84/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8915 - loss: 0.3794 - val_accuracy: 0.8250 - val_loss: 0.4654
# Epoch 85/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8936 - loss: 0.3751 - val_accuracy: 0.8333 - val_loss: 0.4612
# Epoch 86/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8980 - loss: 0.3710 - val_accuracy: 0.8417 - val_loss: 0.4574
# Epoch 87/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9001 - loss: 0.3672 - val_accuracy: 0.8500 - val_loss: 0.4536
# Epoch 88/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9003 - loss: 0.3633 - val_accuracy: 0.8417 - val_loss: 0.4500
# Epoch 89/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9005 - loss: 0.3596 - val_accuracy: 0.8417 - val_loss: 0.4460
# Epoch 90/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9007 - loss: 0.3559 - val_accuracy: 0.8417 - val_loss: 0.4419
# Epoch 91/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9019 - loss: 0.3524 - val_accuracy: 0.8417 - val_loss: 0.4381
# Epoch 92/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9019 - loss: 0.3487 - val_accuracy: 0.8417 - val_loss: 0.4349
# Epoch 93/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9021 - loss: 0.3455 - val_accuracy: 0.8417 - val_loss: 0.4319
# Epoch 94/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9036 - loss: 0.3422 - val_accuracy: 0.8417 - val_loss: 0.4282
# Epoch 95/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9043 - loss: 0.3389 - val_accuracy: 0.8417 - val_loss: 0.4256
# Epoch 96/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9067 - loss: 0.3358 - val_accuracy: 0.8417 - val_loss: 0.4212
# Epoch 97/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9062 - loss: 0.3325 - val_accuracy: 0.8417 - val_loss: 0.4193
# Epoch 98/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9084 - loss: 0.3295 - val_accuracy: 0.8417 - val_loss: 0.4158
# Epoch 99/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9071 - loss: 0.3265 - val_accuracy: 0.8417 - val_loss: 0.4128
# Epoch 100/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9072 - loss: 0.3236 - val_accuracy: 0.8417 - val_loss: 0.4095
# Epoch 101/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9088 - loss: 0.3206 - val_accuracy: 0.8417 - val_loss: 0.4069
# Epoch 102/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9088 - loss: 0.3178 - val_accuracy: 0.8417 - val_loss: 0.4037
# Epoch 103/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9088 - loss: 0.3148 - val_accuracy: 0.8500 - val_loss: 0.4009
# Epoch 104/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9095 - loss: 0.3120 - val_accuracy: 0.8417 - val_loss: 0.3983
# Epoch 105/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9110 - loss: 0.3092 - val_accuracy: 0.8500 - val_loss: 0.3954
# Epoch 106/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9110 - loss: 0.3064 - val_accuracy: 0.8500 - val_loss: 0.3922
# Epoch 107/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9110 - loss: 0.3036 - val_accuracy: 0.8583 - val_loss: 0.3897
# Epoch 108/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9111 - loss: 0.3011 - val_accuracy: 0.8583 - val_loss: 0.3870
# Epoch 109/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9111 - loss: 0.2985 - val_accuracy: 0.8667 - val_loss: 0.3843
# Epoch 110/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9126 - loss: 0.2961 - val_accuracy: 0.8583 - val_loss: 0.3816
# Epoch 111/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9147 - loss: 0.2935 - val_accuracy: 0.8667 - val_loss: 0.3792
# Epoch 112/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9147 - loss: 0.2910 - val_accuracy: 0.8667 - val_loss: 0.3768
# Epoch 113/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9147 - loss: 0.2886 - val_accuracy: 0.8667 - val_loss: 0.3742
# Epoch 114/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9156 - loss: 0.2862 - val_accuracy: 0.8667 - val_loss: 0.3725
# Epoch 115/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9156 - loss: 0.2838 - val_accuracy: 0.8667 - val_loss: 0.3695
# Epoch 116/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9157 - loss: 0.2814 - val_accuracy: 0.8667 - val_loss: 0.3672
# Epoch 117/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9162 - loss: 0.2791 - val_accuracy: 0.8667 - val_loss: 0.3647
# Epoch 118/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9157 - loss: 0.2768 - val_accuracy: 0.8750 - val_loss: 0.3628
# Epoch 119/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9157 - loss: 0.2747 - val_accuracy: 0.8667 - val_loss: 0.3605
# Epoch 120/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9157 - loss: 0.2725 - val_accuracy: 0.8750 - val_loss: 0.3584
# Epoch 121/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9183 - loss: 0.2703 - val_accuracy: 0.8750 - val_loss: 0.3565
# Epoch 122/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9186 - loss: 0.2682 - val_accuracy: 0.8833 - val_loss: 0.3540
# Epoch 123/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9201 - loss: 0.2663 - val_accuracy: 0.8833 - val_loss: 0.3528
# Epoch 124/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9212 - loss: 0.2642 - val_accuracy: 0.8833 - val_loss: 0.3497
# Epoch 125/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9206 - loss: 0.2624 - val_accuracy: 0.8833 - val_loss: 0.3478
# Epoch 126/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9212 - loss: 0.2603 - val_accuracy: 0.8833 - val_loss: 0.3458
# Epoch 127/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9218 - loss: 0.2585 - val_accuracy: 0.8833 - val_loss: 0.3434
# Epoch 128/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9213 - loss: 0.2566 - val_accuracy: 0.8833 - val_loss: 0.3417
# Epoch 129/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9259 - loss: 0.2549 - val_accuracy: 0.8833 - val_loss: 0.3389
# Epoch 130/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9245 - loss: 0.2531 - val_accuracy: 0.8917 - val_loss: 0.3377
# Epoch 131/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9280 - loss: 0.2512 - val_accuracy: 0.8917 - val_loss: 0.3351
# Epoch 132/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9295 - loss: 0.2494 - val_accuracy: 0.8917 - val_loss: 0.3338
# Epoch 133/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9300 - loss: 0.2475 - val_accuracy: 0.8917 - val_loss: 0.3317
# Epoch 134/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9303 - loss: 0.2459 - val_accuracy: 0.8917 - val_loss: 0.3303
# Epoch 135/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9317 - loss: 0.2440 - val_accuracy: 0.8917 - val_loss: 0.3283
# Epoch 136/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9306 - loss: 0.2423 - val_accuracy: 0.8917 - val_loss: 0.3265
# Epoch 137/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9317 - loss: 0.2406 - val_accuracy: 0.8917 - val_loss: 0.3250
# Epoch 138/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9328 - loss: 0.2390 - val_accuracy: 0.8917 - val_loss: 0.3228
# Epoch 139/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9328 - loss: 0.2375 - val_accuracy: 0.8917 - val_loss: 0.3218
# Epoch 140/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9338 - loss: 0.2358 - val_accuracy: 0.8917 - val_loss: 0.3196
# Epoch 141/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9340 - loss: 0.2343 - val_accuracy: 0.8917 - val_loss: 0.3178
# Epoch 142/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9358 - loss: 0.2327 - val_accuracy: 0.8917 - val_loss: 0.3165
# Epoch 143/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9368 - loss: 0.2311 - val_accuracy: 0.8917 - val_loss: 0.3150
# Epoch 144/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9371 - loss: 0.2297 - val_accuracy: 0.8917 - val_loss: 0.3133
# Epoch 145/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9395 - loss: 0.2282 - val_accuracy: 0.8917 - val_loss: 0.3118
# Epoch 146/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9380 - loss: 0.2267 - val_accuracy: 0.8917 - val_loss: 0.3105
# Epoch 147/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9400 - loss: 0.2252 - val_accuracy: 0.8917 - val_loss: 0.3082
# Epoch 148/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9385 - loss: 0.2239 - val_accuracy: 0.8917 - val_loss: 0.3071
# Epoch 149/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9389 - loss: 0.2224 - val_accuracy: 0.8917 - val_loss: 0.3056
# Epoch 150/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9395 - loss: 0.2212 - val_accuracy: 0.8917 - val_loss: 0.3042
# Epoch 151/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9406 - loss: 0.2195 - val_accuracy: 0.8917 - val_loss: 0.3032
# Epoch 152/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9422 - loss: 0.2182 - val_accuracy: 0.8917 - val_loss: 0.3014
# Epoch 153/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9406 - loss: 0.2168 - val_accuracy: 0.8917 - val_loss: 0.3006
# Epoch 154/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9424 - loss: 0.2154 - val_accuracy: 0.8917 - val_loss: 0.2986
# Epoch 155/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9420 - loss: 0.2142 - val_accuracy: 0.8917 - val_loss: 0.2977
# Epoch 156/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9431 - loss: 0.2130 - val_accuracy: 0.8917 - val_loss: 0.2965
# Epoch 157/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9434 - loss: 0.2116 - val_accuracy: 0.9000 - val_loss: 0.2951
# Epoch 158/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9434 - loss: 0.2104 - val_accuracy: 0.9000 - val_loss: 0.2939
# Epoch 159/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9434 - loss: 0.2090 - val_accuracy: 0.9000 - val_loss: 0.2923
# Epoch 160/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9431 - loss: 0.2078 - val_accuracy: 0.9000 - val_loss: 0.2909
# Epoch 161/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9436 - loss: 0.2066 - val_accuracy: 0.9000 - val_loss: 0.2901
# Epoch 162/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9441 - loss: 0.2052 - val_accuracy: 0.9000 - val_loss: 0.2886
# Epoch 163/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9447 - loss: 0.2041 - val_accuracy: 0.9000 - val_loss: 0.2877
# Epoch 164/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9447 - loss: 0.2029 - val_accuracy: 0.9000 - val_loss: 0.2864
# Epoch 165/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9444 - loss: 0.2015 - val_accuracy: 0.9000 - val_loss: 0.2853
# Epoch 166/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9455 - loss: 0.2006 - val_accuracy: 0.9000 - val_loss: 0.2842
# Epoch 167/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9474 - loss: 0.1993 - val_accuracy: 0.9000 - val_loss: 0.2831
# Epoch 168/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9454 - loss: 0.1982 - val_accuracy: 0.9000 - val_loss: 0.2818
# Epoch 169/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9472 - loss: 0.1971 - val_accuracy: 0.9000 - val_loss: 0.2808
# Epoch 170/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9477 - loss: 0.1961 - val_accuracy: 0.9000 - val_loss: 0.2801
# Epoch 171/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9472 - loss: 0.1951 - val_accuracy: 0.9000 - val_loss: 0.2786
# Epoch 172/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9477 - loss: 0.1939 - val_accuracy: 0.9000 - val_loss: 0.2777
# Epoch 173/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9474 - loss: 0.1928 - val_accuracy: 0.9000 - val_loss: 0.2766
# Epoch 174/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9480 - loss: 0.1916 - val_accuracy: 0.9000 - val_loss: 0.2754
# Epoch 175/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9484 - loss: 0.1906 - val_accuracy: 0.9000 - val_loss: 0.2745
# Epoch 176/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9484 - loss: 0.1897 - val_accuracy: 0.9000 - val_loss: 0.2736
# Epoch 177/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9484 - loss: 0.1885 - val_accuracy: 0.9000 - val_loss: 0.2730
# Epoch 178/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9484 - loss: 0.1877 - val_accuracy: 0.8917 - val_loss: 0.2725
# Epoch 179/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9484 - loss: 0.1863 - val_accuracy: 0.8917 - val_loss: 0.2715
# Epoch 180/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9462 - loss: 0.1855 - val_accuracy: 0.8917 - val_loss: 0.2707
# Epoch 181/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9462 - loss: 0.1845 - val_accuracy: 0.8917 - val_loss: 0.2699
# Epoch 182/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9462 - loss: 0.1836 - val_accuracy: 0.8917 - val_loss: 0.2692
# Epoch 183/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9462 - loss: 0.1826 - val_accuracy: 0.8917 - val_loss: 0.2684
# Epoch 184/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9486 - loss: 0.1817 - val_accuracy: 0.8917 - val_loss: 0.2671
# Epoch 185/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9486 - loss: 0.1806 - val_accuracy: 0.8917 - val_loss: 0.2669
# Epoch 186/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9486 - loss: 0.1798 - val_accuracy: 0.8917 - val_loss: 0.2659
# Epoch 187/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9486 - loss: 0.1786 - val_accuracy: 0.8917 - val_loss: 0.2645
# Epoch 188/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9486 - loss: 0.1779 - val_accuracy: 0.8917 - val_loss: 0.2643
# Epoch 189/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9486 - loss: 0.1768 - val_accuracy: 0.9000 - val_loss: 0.2634
# Epoch 190/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9517 - loss: 0.1761 - val_accuracy: 0.9000 - val_loss: 0.2624
# Epoch 191/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9517 - loss: 0.1751 - val_accuracy: 0.9000 - val_loss: 0.2616
# Epoch 192/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9529 - loss: 0.1743 - val_accuracy: 0.9000 - val_loss: 0.2609
# Epoch 193/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9529 - loss: 0.1734 - val_accuracy: 0.9000 - val_loss: 0.2604
# Epoch 194/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9551 - loss: 0.1726 - val_accuracy: 0.9000 - val_loss: 0.2601
# Epoch 195/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9529 - loss: 0.1717 - val_accuracy: 0.9000 - val_loss: 0.2592
# Epoch 196/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9560 - loss: 0.1708 - val_accuracy: 0.9000 - val_loss: 0.2584
# Epoch 197/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9570 - loss: 0.1701 - val_accuracy: 0.9000 - val_loss: 0.2585
# Epoch 198/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9565 - loss: 0.1690 - val_accuracy: 0.9000 - val_loss: 0.2574
# Epoch 199/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9588 - loss: 0.1684 - val_accuracy: 0.9000 - val_loss: 0.2575
# Epoch 200/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9592 - loss: 0.1676 - val_accuracy: 0.9000 - val_loss: 0.2563
# Epoch 201/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9598 - loss: 0.1668 - val_accuracy: 0.9000 - val_loss: 0.2568
# Epoch 202/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9593 - loss: 0.1661 - val_accuracy: 0.9000 - val_loss: 0.2546
# Epoch 203/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9598 - loss: 0.1654 - val_accuracy: 0.9000 - val_loss: 0.2560
# Epoch 204/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9601 - loss: 0.1643 - val_accuracy: 0.9000 - val_loss: 0.2536
# Epoch 205/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9613 - loss: 0.1639 - val_accuracy: 0.9000 - val_loss: 0.2552
# Epoch 206/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9601 - loss: 0.1629 - val_accuracy: 0.9000 - val_loss: 0.2533
# Epoch 207/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9601 - loss: 0.1624 - val_accuracy: 0.9000 - val_loss: 0.2541
# Epoch 208/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9601 - loss: 0.1617 - val_accuracy: 0.9000 - val_loss: 0.2528
# Epoch 209/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9601 - loss: 0.1611 - val_accuracy: 0.9000 - val_loss: 0.2532
# Epoch 210/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9601 - loss: 0.1604 - val_accuracy: 0.9000 - val_loss: 0.2525
# Epoch 211/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9613 - loss: 0.1597 - val_accuracy: 0.9000 - val_loss: 0.2513
# Epoch 212/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9613 - loss: 0.1590 - val_accuracy: 0.9000 - val_loss: 0.2537
# Epoch 213/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9613 - loss: 0.1580 - val_accuracy: 0.9000 - val_loss: 0.2523
# Epoch 214/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9616 - loss: 0.1577 - val_accuracy: 0.9000 - val_loss: 0.2524
# Epoch 215/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9603 - loss: 0.1569 - val_accuracy: 0.9000 - val_loss: 0.2527
# Epoch 216/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9597 - loss: 0.1563 - val_accuracy: 0.9000 - val_loss: 0.2513
# Epoch 217/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9603 - loss: 0.1559 - val_accuracy: 0.9000 - val_loss: 0.2529
# Epoch 218/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9610 - loss: 0.1550 - val_accuracy: 0.9000 - val_loss: 0.2513
# Epoch 219/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9616 - loss: 0.1543 - val_accuracy: 0.9000 - val_loss: 0.2525
# Epoch 220/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9610 - loss: 0.1538 - val_accuracy: 0.9000 - val_loss: 0.2525
# Epoch 221/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9610 - loss: 0.1531 - val_accuracy: 0.9083 - val_loss: 0.2527
# Epoch 222/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9615 - loss: 0.1526 - val_accuracy: 0.8917 - val_loss: 0.2522
# Epoch 223/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9615 - loss: 0.1518 - val_accuracy: 0.9083 - val_loss: 0.2520
# Epoch 224/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9626 - loss: 0.1514 - val_accuracy: 0.8917 - val_loss: 0.2516
# Epoch 225/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9620 - loss: 0.1506 - val_accuracy: 0.9000 - val_loss: 0.2544
# Epoch 226/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9626 - loss: 0.1499 - val_accuracy: 0.9000 - val_loss: 0.2515
# Epoch 227/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9629 - loss: 0.1492 - val_accuracy: 0.9000 - val_loss: 0.2538
# Epoch 228/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9615 - loss: 0.1484 - val_accuracy: 0.9000 - val_loss: 0.2534
# Epoch 229/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9617 - loss: 0.1479 - val_accuracy: 0.9083 - val_loss: 0.2525
# Epoch 230/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9615 - loss: 0.1476 - val_accuracy: 0.9083 - val_loss: 0.2512
# Epoch 231/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9607 - loss: 0.1468 - val_accuracy: 0.9083 - val_loss: 0.2530
# Epoch 232/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9592 - loss: 0.1467 - val_accuracy: 0.9083 - val_loss: 0.2529
# Epoch 233/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9596 - loss: 0.1461 - val_accuracy: 0.9083 - val_loss: 0.2541
# Epoch 234/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9597 - loss: 0.1455 - val_accuracy: 0.9083 - val_loss: 0.2529
# Epoch 235/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9604 - loss: 0.1452 - val_accuracy: 0.9083 - val_loss: 0.2526
# Epoch 236/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9604 - loss: 0.1448 - val_accuracy: 0.9083 - val_loss: 0.2547
# Epoch 237/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9609 - loss: 0.1441 - val_accuracy: 0.9083 - val_loss: 0.2529
# Epoch 238/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9631 - loss: 0.1437 - val_accuracy: 0.9083 - val_loss: 0.2535
# Epoch 239/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9609 - loss: 0.1433 - val_accuracy: 0.9083 - val_loss: 0.2535
# Epoch 240/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9614 - loss: 0.1426 - val_accuracy: 0.9083 - val_loss: 0.2526
# Epoch 241/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9628 - loss: 0.1418 - val_accuracy: 0.9083 - val_loss: 0.2543
# Epoch 242/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9628 - loss: 0.1418 - val_accuracy: 0.9083 - val_loss: 0.2546
# Epoch 243/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9628 - loss: 0.1414 - val_accuracy: 0.9083 - val_loss: 0.2548
# Epoch 244/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9629 - loss: 0.1409 - val_accuracy: 0.9083 - val_loss: 0.2539
# Epoch 245/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9628 - loss: 0.1405 - val_accuracy: 0.9083 - val_loss: 0.2542
# Epoch 246/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9628 - loss: 0.1400 - val_accuracy: 0.9083 - val_loss: 0.2537
# Epoch 247/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9628 - loss: 0.1392 - val_accuracy: 0.9083 - val_loss: 0.2540
# Epoch 248/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9628 - loss: 0.1388 - val_accuracy: 0.9083 - val_loss: 0.2537
# Epoch 249/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9626 - loss: 0.1384 - val_accuracy: 0.9083 - val_loss: 0.2538
# Epoch 250/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9626 - loss: 0.1378 - val_accuracy: 0.9083 - val_loss: 0.2544
# Epoch 251/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9634 - loss: 0.1379 - val_accuracy: 0.9083 - val_loss: 0.2542
# Epoch 252/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9622 - loss: 0.1374 - val_accuracy: 0.9083 - val_loss: 0.2552
# Epoch 253/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9625 - loss: 0.1369 - val_accuracy: 0.9083 - val_loss: 0.2537
# Epoch 254/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9593 - loss: 0.1363 - val_accuracy: 0.9083 - val_loss: 0.2538
# Epoch 255/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9671 - loss: 0.1360 - val_accuracy: 0.9083 - val_loss: 0.2539
# Epoch 256/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9616 - loss: 0.1363 - val_accuracy: 0.9083 - val_loss: 0.2541
# Epoch 257/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9635 - loss: 0.1357 - val_accuracy: 0.9083 - val_loss: 0.2535
# Epoch 258/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9601 - loss: 0.1354 - val_accuracy: 0.9083 - val_loss: 0.2537
# Epoch 259/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9594 - loss: 0.1345 - val_accuracy: 0.9083 - val_loss: 0.2519
# Epoch 260/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9588 - loss: 0.1345 - val_accuracy: 0.9083 - val_loss: 0.2523
# Epoch 261/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9600 - loss: 0.1336 - val_accuracy: 0.9167 - val_loss: 0.2522
# Epoch 262/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9586 - loss: 0.1337 - val_accuracy: 0.9167 - val_loss: 0.2521
# Epoch 263/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9581 - loss: 0.1335 - val_accuracy: 0.9167 - val_loss: 0.2523
# Epoch 264/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9579 - loss: 0.1333 - val_accuracy: 0.9167 - val_loss: 0.2530
# Epoch 265/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9573 - loss: 0.1332 - val_accuracy: 0.9167 - val_loss: 0.2564
# Epoch 266/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9589 - loss: 0.1334 - val_accuracy: 0.9083 - val_loss: 0.2609
# Epoch 267/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9605 - loss: 0.1336 - val_accuracy: 0.8917 - val_loss: 0.2714
# Epoch 268/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9612 - loss: 0.1354 - val_accuracy: 0.8833 - val_loss: 0.2735
# Epoch 269/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9630 - loss: 0.1362 - val_accuracy: 0.8917 - val_loss: 0.2786
# Epoch 270/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9620 - loss: 0.1369 - val_accuracy: 0.8917 - val_loss: 0.2811
# Epoch 271/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9624 - loss: 0.1373 - val_accuracy: 0.8833 - val_loss: 0.2792
# Epoch 272/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9569 - loss: 0.1372 - val_accuracy: 0.8917 - val_loss: 0.2848
# Epoch 273/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9587 - loss: 0.1374 - val_accuracy: 0.9000 - val_loss: 0.2846
# Epoch 274/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9555 - loss: 0.1379 - val_accuracy: 0.8917 - val_loss: 0.2842
# Epoch 275/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9576 - loss: 0.1367 - val_accuracy: 0.9000 - val_loss: 0.2806
# Epoch 276/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9598 - loss: 0.1353 - val_accuracy: 0.9000 - val_loss: 0.2783
# Epoch 277/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9563 - loss: 0.1338 - val_accuracy: 0.9000 - val_loss: 0.2764
# Epoch 278/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9598 - loss: 0.1323 - val_accuracy: 0.9083 - val_loss: 0.2732
# Epoch 279/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9602 - loss: 0.1302 - val_accuracy: 0.9083 - val_loss: 0.2716
# Epoch 280/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9598 - loss: 0.1289 - val_accuracy: 0.9083 - val_loss: 0.2710
# Epoch 281/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9623 - loss: 0.1278 - val_accuracy: 0.9083 - val_loss: 0.2687
# Epoch 282/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9612 - loss: 0.1267 - val_accuracy: 0.9083 - val_loss: 0.2681
# Epoch 283/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9623 - loss: 0.1253 - val_accuracy: 0.9083 - val_loss: 0.2660
# Epoch 284/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9637 - loss: 0.1243 - val_accuracy: 0.9083 - val_loss: 0.2661
# Epoch 285/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9642 - loss: 0.1232 - val_accuracy: 0.9083 - val_loss: 0.2644
# Epoch 286/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9657 - loss: 0.1219 - val_accuracy: 0.9083 - val_loss: 0.2637
# Epoch 287/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9659 - loss: 0.1204 - val_accuracy: 0.9083 - val_loss: 0.2644
# Epoch 288/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9670 - loss: 0.1193 - val_accuracy: 0.9083 - val_loss: 0.2647
# Epoch 289/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9677 - loss: 0.1183 - val_accuracy: 0.9083 - val_loss: 0.2642
# Epoch 290/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9677 - loss: 0.1172 - val_accuracy: 0.9167 - val_loss: 0.2659
# Epoch 291/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9682 - loss: 0.1162 - val_accuracy: 0.9167 - val_loss: 0.2655
# Epoch 292/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9677 - loss: 0.1156 - val_accuracy: 0.9167 - val_loss: 0.2687
# Epoch 293/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9698 - loss: 0.1155 - val_accuracy: 0.9167 - val_loss: 0.2699
# Epoch 294/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9708 - loss: 0.1150 - val_accuracy: 0.9167 - val_loss: 0.2690
# Epoch 295/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9703 - loss: 0.1143 - val_accuracy: 0.9167 - val_loss: 0.2706
# Epoch 296/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9716 - loss: 0.1133 - val_accuracy: 0.9167 - val_loss: 0.2674
# Epoch 297/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9685 - loss: 0.1123 - val_accuracy: 0.9167 - val_loss: 0.2704
# Epoch 298/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9721 - loss: 0.1114 - val_accuracy: 0.9167 - val_loss: 0.2683
# Epoch 299/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9725 - loss: 0.1107 - val_accuracy: 0.9167 - val_loss: 0.2689
# Epoch 300/300
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9714 - loss: 0.1104 - val_accuracy: 0.9167 - val_loss: 0.2705

# %% [markdown]
# <a name='5'></a>
# ## 5 - History Object
#
# The history object is an output of the `.fit()` operation, and provides a record of all the loss and metric values in memory. It's stored as a dictionary that you can retrieve at `history.history`:

# %%
history.history
# Out:
# {'accuracy': [0.19629628956317902,
#   0.2222222238779068,
#   0.2212962955236435,
#   0.2361111044883728,
#   0.30092594027519226,
#   0.32870370149612427,
#   0.39351850748062134,
#   0.4175925850868225,
#   0.4342592656612396,
#   0.43703705072402954,
#   0.45185184478759766,
#   0.4546296298503876,
#   0.4749999940395355,
#   0.49351853132247925,
#   0.5055555701255798,
#   0.5314815044403076,
#   0.5574073791503906,
#   0.5777778029441833,
#   0.604629635810852,
#   0.6138888597488403,
#   0.6296296119689941,
#   0.6481481194496155,
#   0.6583333611488342,
#   0.664814829826355,
#   0.6722221970558167,
#   0.6796296238899231,
#   0.6898148059844971,
#   0.6962962746620178,
#   0.7083333134651184,
#   0.7175925970077515,
#   0.7259259223937988,
#   0.730555534362793,
#   0.7370370626449585,
#   0.7425925731658936,
#   0.7509258985519409,
#   0.7546296119689941,
#   0.7675926089286804,
#   0.7722222208976746,
#   0.7749999761581421,
#   0.7824074029922485,
#   0.7888888716697693,
#   0.7953703999519348,
#   0.8009259104728699,
#   0.8046296238899231,
#   0.8092592358589172,
#   0.8101851940155029,
#   0.8101851940155029,
#   0.8175926208496094,
#   0.8212962746620178,
#   0.8268518447875977,
#   0.8268518447875977,
#   0.8277778029441833,
#   0.8296296000480652,
#   0.8342592716217041,
#   0.8370370268821716,
#   0.8370370268821716,
#   0.8398148417472839,
#   0.8416666388511658,
#   0.8435184955596924,
#   0.8462963104248047,
#   0.8490740656852722,
#   0.8527777791023254,
#   0.854629635810852,
#   0.855555534362793,
#   0.8592592477798462,
#   0.8574073910713196,
#   0.8601852059364319,
#   0.8611111044883728,
#   0.8638888597488403,
#   0.8675925731658936,
#   0.8675925731658936,
#   0.8703703880310059,
#   0.8731481432914734,
#   0.8731481432914734,
#   0.8768518567085266,
#   0.8796296119689941,
#   0.8796296119689941,
#   0.8796296119689941,
#   0.8814814686775208,
#   0.8824074268341064,
#   0.8824074268341064,
#   0.8842592835426331,
#   0.8833333253860474,
#   0.885185182094574,
#   0.8879629373550415,
#   0.8916666507720947,
#   0.8925926089286804,
#   0.8935185074806213,
#   0.894444465637207,
#   0.895370364189148,
#   0.8962963223457336,
#   0.8962963223457336,
#   0.8972222208976746,
#   0.8981481194496155,
#   0.8990740776062012,
#   0.9009259343147278,
#   0.9009259343147278,
#   0.9027777910232544,
#   0.9027777910232544,
#   0.9037036895751953,
#   0.9055555462837219,
#   0.9055555462837219,
#   0.9055555462837219,
#   0.9064815044403076,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9092592597007751,
#   0.9092592597007751,
#   0.9101851582527161,
#   0.9111111164093018,
#   0.9111111164093018,
#   0.9111111164093018,
#   0.9120370149612427,
#   0.9120370149612427,
#   0.9120370149612427,
#   0.9129629731178284,
#   0.9120370149612427,
#   0.9120370149612427,
#   0.9120370149612427,
#   0.9120370149612427,
#   0.9129629731178284,
#   0.9138888716697693,
#   0.9157407283782959,
#   0.914814829826355,
#   0.9157407283782959,
#   0.9166666865348816,
#   0.9157407283782959,
#   0.9203703999519348,
#   0.9185185432434082,
#   0.9212962985038757,
#   0.9222221970558167,
#   0.9231481552124023,
#   0.9240740537643433,
#   0.925000011920929,
#   0.925000011920929,
#   0.925000011920929,
#   0.9268518686294556,
#   0.9268518686294556,
#   0.9268518686294556,
#   0.9277777671813965,
#   0.9296296238899231,
#   0.9314814805984497,
#   0.9314814805984497,
#   0.9333333373069763,
#   0.9324073791503906,
#   0.9351851940155029,
#   0.9333333373069763,
#   0.9342592358589172,
#   0.9351851940155029,
#   0.9361110925674438,
#   0.9370370507240295,
#   0.9361110925674438,
#   0.9379629492759705,
#   0.9379629492759705,
#   0.9379629492759705,
#   0.9388889074325562,
#   0.9388889074325562,
#   0.9388889074325562,
#   0.9379629492759705,
#   0.9398148059844971,
#   0.9398148059844971,
#   0.9416666626930237,
#   0.9416666626930237,
#   0.9407407641410828,
#   0.9435185194015503,
#   0.9435185194015503,
#   0.9425926208496094,
#   0.9425926208496094,
#   0.9444444179534912,
#   0.9425926208496094,
#   0.9444444179534912,
#   0.9435185194015503,
#   0.9444444179534912,
#   0.9453703761100769,
#   0.9453703761100769,
#   0.9453703761100769,
#   0.9453703761100769,
#   0.9453703761100769,
#   0.9444444179534912,
#   0.9444444179534912,
#   0.9444444179534912,
#   0.9444444179534912,
#   0.9462962746620178,
#   0.9462962746620178,
#   0.9462962746620178,
#   0.9462962746620178,
#   0.9462962746620178,
#   0.9462962746620178,
#   0.9472222328186035,
#   0.9472222328186035,
#   0.9481481313705444,
#   0.9481481313705444,
#   0.9490740895271301,
#   0.9481481313705444,
#   0.949999988079071,
#   0.9509259462356567,
#   0.9509259462356567,
#   0.9518518447875977,
#   0.9527778029441833,
#   0.9537037014961243,
#   0.9527778029441833,
#   0.9537037014961243,
#   0.9546296000480652,
#   0.9555555582046509,
#   0.9546296000480652,
#   0.9546296000480652,
#   0.9546296000480652,
#   0.9546296000480652,
#   0.9546296000480652,
#   0.9555555582046509,
#   0.9555555582046509,
#   0.9555555582046509,
#   0.9564814567565918,
#   0.9555555582046509,
#   0.9546296000480652,
#   0.9555555582046509,
#   0.9555555582046509,
#   0.9564814567565918,
#   0.9555555582046509,
#   0.9555555582046509,
#   0.9564814567565918,
#   0.9564814567565918,
#   0.9574074149131775,
#   0.9574074149131775,
#   0.9574074149131775,
#   0.9583333134651184,
#   0.9574074149131775,
#   0.9583333134651184,
#   0.9564814567565918,
#   0.9546296000480652,
#   0.9555555582046509,
#   0.9564814567565918,
#   0.9574074149131775,
#   0.9583333134651184,
#   0.9583333134651184,
#   0.9583333134651184,
#   0.960185170173645,
#   0.9583333134651184,
#   0.9583333134651184,
#   0.9592592716217041,
#   0.9592592716217041,
#   0.9592592716217041,
#   0.9592592716217041,
#   0.9592592716217041,
#   0.9592592716217041,
#   0.9592592716217041,
#   0.9592592716217041,
#   0.9583333134651184,
#   0.9583333134651184,
#   0.9592592716217041,
#   0.9583333134651184,
#   0.9592592716217041,
#   0.9583333134651184,
#   0.9620370268821716,
#   0.9592592716217041,
#   0.9611111283302307,
#   0.9592592716217041,
#   0.9583333134651184,
#   0.9574074149131775,
#   0.9583333134651184,
#   0.9574074149131775,
#   0.9564814567565918,
#   0.9564814567565918,
#   0.9564814567565918,
#   0.9564814567565918,
#   0.9583333134651184,
#   0.9592592716217041,
#   0.960185170173645,
#   0.9592592716217041,
#   0.9629629850387573,
#   0.9555555582046509,
#   0.9583333134651184,
#   0.9555555582046509,
#   0.9583333134651184,
#   0.9583333134651184,
#   0.9564814567565918,
#   0.9583333134651184,
#   0.9592592716217041,
#   0.9583333134651184,
#   0.9611111283302307,
#   0.9592592716217041,
#   0.9611111283302307,
#   0.9629629850387573,
#   0.9638888835906982,
#   0.9638888835906982,
#   0.9648148417472839,
#   0.9657407402992249,
#   0.9675925970077515,
#   0.9675925970077515,
#   0.9685184955596924,
#   0.9675925970077515,
#   0.9685184955596924,
#   0.970370352268219,
#   0.9694444537162781,
#   0.9712963104248047,
#   0.9694444537162781,
#   0.9722222089767456,
#   0.9731481671333313,
#   0.9712963104248047],
#  'loss': [1.7894376516342163,
#   1.7798810005187988,
#   1.7731140851974487,
#   1.764983057975769,
#   1.7554031610488892,
#   1.7439496517181396,
#   1.7300901412963867,
#   1.7124884128570557,
#   1.6911553144454956,
#   1.6633967161178589,
#   1.630156397819519,
#   1.591739296913147,
#   1.5459272861480713,
#   1.4948880672454834,
#   1.4395440816879272,
#   1.378896713256836,
#   1.3187799453735352,
#   1.2638049125671387,
#   1.2129125595092773,
#   1.168758511543274,
#   1.1280628442764282,
#   1.0947877168655396,
#   1.0629005432128906,
#   1.032932162284851,
#   1.007045865058899,
#   0.9808844923973083,
#   0.9580556154251099,
#   0.9365744590759277,
#   0.9153927564620972,
#   0.8957011699676514,
#   0.878007709980011,
#   0.8607034087181091,
#   0.8443963527679443,
#   0.8283214569091797,
#   0.812886118888855,
#   0.7981649041175842,
#   0.7837075591087341,
#   0.7696173787117004,
#   0.7566013932228088,
#   0.743375301361084,
#   0.7303540110588074,
#   0.7170917987823486,
#   0.7040436267852783,
#   0.6918945908546448,
#   0.6798838973045349,
#   0.6677873134613037,
#   0.6567146182060242,
#   0.6455806493759155,
#   0.6347792744636536,
#   0.6241137981414795,
#   0.6134607195854187,
#   0.6032141447067261,
#   0.5935738682746887,
#   0.583767831325531,
#   0.5747566223144531,
#   0.5657310485839844,
#   0.5569643974304199,
#   0.5485562086105347,
#   0.5402753353118896,
#   0.5324912071228027,
#   0.5247231125831604,
#   0.5173164010047913,
#   0.510129451751709,
#   0.5031558275222778,
#   0.4961528778076172,
#   0.48918473720550537,
#   0.4825688600540161,
#   0.47621941566467285,
#   0.4697151184082031,
#   0.46354979276657104,
#   0.4572871923446655,
#   0.4510246515274048,
#   0.44497671723365784,
#   0.43922218680381775,
#   0.43337884545326233,
#   0.4277942180633545,
#   0.4225296378135681,
#   0.4172764718532562,
#   0.4121802747249603,
#   0.4073086380958557,
#   0.4025998115539551,
#   0.3979826867580414,
#   0.39347773790359497,
#   0.3892585039138794,
#   0.38492754101753235,
#   0.3808572292327881,
#   0.3769075572490692,
#   0.3730519115924835,
#   0.3692374527454376,
#   0.3655205965042114,
#   0.3619237244129181,
#   0.3581823706626892,
#   0.3549434542655945,
#   0.35167086124420166,
#   0.3482138514518738,
#   0.3450429141521454,
#   0.3418530523777008,
#   0.33871176838874817,
#   0.3356035649776459,
#   0.3327455520629883,
#   0.32971709966659546,
#   0.3268917202949524,
#   0.32391467690467834,
#   0.3209574520587921,
#   0.3182833790779114,
#   0.3154570758342743,
#   0.3127247989177704,
#   0.3103111684322357,
#   0.3076316714286804,
#   0.30519530177116394,
#   0.3027275502681732,
#   0.3001585304737091,
#   0.2978407144546509,
#   0.29554370045661926,
#   0.2931400239467621,
#   0.2908274829387665,
#   0.2884874641895294,
#   0.28631776571273804,
#   0.28420451283454895,
#   0.28202909231185913,
#   0.279880166053772,
#   0.2778483033180237,
#   0.27596455812454224,
#   0.27398380637168884,
#   0.27206388115882874,
#   0.2700715959072113,
#   0.26829448342323303,
#   0.2663465738296509,
#   0.26447978615760803,
#   0.2626858055591583,
#   0.26064759492874146,
#   0.25894129276275635,
#   0.257144033908844,
#   0.2555255889892578,
#   0.25358185172080994,
#   0.2519911229610443,
#   0.2502518594264984,
#   0.24869023263454437,
#   0.24711467325687408,
#   0.24539799988269806,
#   0.24383090436458588,
#   0.24226363003253937,
#   0.24074359238147736,
#   0.23920047283172607,
#   0.23789694905281067,
#   0.23629935085773468,
#   0.23486842215061188,
#   0.23348774015903473,
#   0.23193438351154327,
#   0.23059801757335663,
#   0.2290438860654831,
#   0.22769303619861603,
#   0.22634264826774597,
#   0.22484612464904785,
#   0.22375428676605225,
#   0.2223513275384903,
#   0.22103211283683777,
#   0.21977774798870087,
#   0.21848642826080322,
#   0.21724383533000946,
#   0.2160179764032364,
#   0.2145894467830658,
#   0.21359539031982422,
#   0.2124042510986328,
#   0.2110804170370102,
#   0.21015864610671997,
#   0.20885631442070007,
#   0.20780068635940552,
#   0.2066989690065384,
#   0.20573849976062775,
#   0.20457470417022705,
#   0.2034926414489746,
#   0.20230360329151154,
#   0.2011083960533142,
#   0.20007608830928802,
#   0.1991431564092636,
#   0.1978958696126938,
#   0.1970146745443344,
#   0.1957107037305832,
#   0.19487743079662323,
#   0.19382965564727783,
#   0.19294026494026184,
#   0.19191506505012512,
#   0.19092974066734314,
#   0.18989402055740356,
#   0.18892383575439453,
#   0.187856063246727,
#   0.18714264035224915,
#   0.18613363802433014,
#   0.18524406850337982,
#   0.18436947464942932,
#   0.18350815773010254,
#   0.18268857896327972,
#   0.18182425200939178,
#   0.1809258610010147,
#   0.17997664213180542,
#   0.17932863533496857,
#   0.17834174633026123,
#   0.17770645022392273,
#   0.17683856189250946,
#   0.17603471875190735,
#   0.17534296214580536,
#   0.17450392246246338,
#   0.1734929233789444,
#   0.17300598323345184,
#   0.17207275331020355,
#   0.17146389186382294,
#   0.17070379853248596,
#   0.1700398325920105,
#   0.16935916244983673,
#   0.1688629686832428,
#   0.16781868040561676,
#   0.1668398082256317,
#   0.1664522886276245,
#   0.16576124727725983,
#   0.16518492996692657,
#   0.16456007957458496,
#   0.16368260979652405,
#   0.1629931479692459,
#   0.16239097714424133,
#   0.16172108054161072,
#   0.16098734736442566,
#   0.16044388711452484,
#   0.15997684001922607,
#   0.159311905503273,
#   0.1588304340839386,
#   0.15803393721580505,
#   0.15699627995491028,
#   0.156615749001503,
#   0.15624722838401794,
#   0.1557837575674057,
#   0.15514427423477173,
#   0.1541881412267685,
#   0.15337520837783813,
#   0.1531408131122589,
#   0.15249711275100708,
#   0.15156693756580353,
#   0.1510746330022812,
#   0.150661438703537,
#   0.14978991448879242,
#   0.14931520819664001,
#   0.1490553468465805,
#   0.14863461256027222,
#   0.14784203469753265,
#   0.1472736895084381,
#   0.14654980599880219,
#   0.1459336280822754,
#   0.14546790719032288,
#   0.14492635428905487,
#   0.14428630471229553,
#   0.14419563114643097,
#   0.14358380436897278,
#   0.14290596544742584,
#   0.14222389459609985,
#   0.14222240447998047,
#   0.14211887121200562,
#   0.14166207611560822,
#   0.14099092781543732,
#   0.14014509320259094,
#   0.14001479744911194,
#   0.13915519416332245,
#   0.13925586640834808,
#   0.13930226862430573,
#   0.13900305330753326,
#   0.13889408111572266,
#   0.13921470940113068,
#   0.1402391493320465,
#   0.1412375420331955,
#   0.14171196520328522,
#   0.1418064385652542,
#   0.14104148745536804,
#   0.1412154883146286,
#   0.14062513411045074,
#   0.1405980885028839,
#   0.13863788545131683,
#   0.13721893727779388,
#   0.13556931912899017,
#   0.13417313992977142,
#   0.1325490027666092,
#   0.13140597939491272,
#   0.13050004839897156,
#   0.12942837178707123,
#   0.12818241119384766,
#   0.12727811932563782,
#   0.12629906833171844,
#   0.12502430379390717,
#   0.12343690544366837,
#   0.12226563692092896,
#   0.12122387439012527,
#   0.11996574699878693,
#   0.11894261091947556,
#   0.1179814338684082,
#   0.11781191825866699,
#   0.11674362421035767,
#   0.11619649082422256,
#   0.11505787819623947,
#   0.1142999678850174,
#   0.11359777301549911,
#   0.1127050593495369,
#   0.11224815249443054],
#  'val_accuracy': [0.2083333283662796,
#   0.2083333283662796,
#   0.22499999403953552,
#   0.34166666865348816,
#   0.38333332538604736,
#   0.42500001192092896,
#   0.4583333432674408,
#   0.4749999940395355,
#   0.46666666865348816,
#   0.4833333194255829,
#   0.4749999940395355,
#   0.4749999940395355,
#   0.5,
#   0.5,
#   0.5583333373069763,
#   0.574999988079071,
#   0.574999988079071,
#   0.574999988079071,
#   0.574999988079071,
#   0.6166666746139526,
#   0.625,
#   0.6166666746139526,
#   0.6583333611488342,
#   0.6499999761581421,
#   0.6333333253860474,
#   0.6416666507720947,
#   0.6583333611488342,
#   0.6666666865348816,
#   0.6833333373069763,
#   0.6916666626930237,
#   0.6916666626930237,
#   0.699999988079071,
#   0.6916666626930237,
#   0.6916666626930237,
#   0.7083333134651184,
#   0.7250000238418579,
#   0.7250000238418579,
#   0.7416666746139526,
#   0.7583333253860474,
#   0.7583333253860474,
#   0.7583333253860474,
#   0.7416666746139526,
#   0.7416666746139526,
#   0.75,
#   0.75,
#   0.75,
#   0.75,
#   0.75,
#   0.7583333253860474,
#   0.7666666507720947,
#   0.7666666507720947,
#   0.7749999761581421,
#   0.7833333611488342,
#   0.7833333611488342,
#   0.7833333611488342,
#   0.7833333611488342,
#   0.7833333611488342,
#   0.7833333611488342,
#   0.7833333611488342,
#   0.7916666865348816,
#   0.7916666865348816,
#   0.7916666865348816,
#   0.7916666865348816,
#   0.7916666865348816,
#   0.7916666865348816,
#   0.7916666865348816,
#   0.7916666865348816,
#   0.7916666865348816,
#   0.7916666865348816,
#   0.800000011920929,
#   0.7916666865348816,
#   0.7916666865348816,
#   0.7916666865348816,
#   0.7916666865348816,
#   0.800000011920929,
#   0.800000011920929,
#   0.8083333373069763,
#   0.8083333373069763,
#   0.8083333373069763,
#   0.8166666626930237,
#   0.824999988079071,
#   0.824999988079071,
#   0.824999988079071,
#   0.824999988079071,
#   0.8333333134651184,
#   0.8416666388511658,
#   0.8500000238418579,
#   0.8416666388511658,
#   0.8416666388511658,
#   0.8416666388511658,
#   0.8416666388511658,
#   0.8416666388511658,
#   0.8416666388511658,
#   0.8416666388511658,
#   0.8416666388511658,
#   0.8416666388511658,
#   0.8416666388511658,
#   0.8416666388511658,
#   0.8416666388511658,
#   0.8416666388511658,
#   0.8416666388511658,
#   0.8416666388511658,
#   0.8500000238418579,
#   0.8416666388511658,
#   0.8500000238418579,
#   0.8500000238418579,
#   0.8583333492279053,
#   0.8583333492279053,
#   0.8666666746139526,
#   0.8583333492279053,
#   0.8666666746139526,
#   0.8666666746139526,
#   0.8666666746139526,
#   0.8666666746139526,
#   0.8666666746139526,
#   0.8666666746139526,
#   0.8666666746139526,
#   0.875,
#   0.8666666746139526,
#   0.875,
#   0.875,
#   0.8833333253860474,
#   0.8833333253860474,
#   0.8833333253860474,
#   0.8833333253860474,
#   0.8833333253860474,
#   0.8833333253860474,
#   0.8833333253860474,
#   0.8833333253860474,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.9083333611488342,
#   0.8916666507720947,
#   0.9083333611488342,
#   0.8916666507720947,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9166666865348816,
#   0.9166666865348816,
#   0.9166666865348816,
#   0.9166666865348816,
#   0.9166666865348816,
#   0.9083333611488342,
#   0.8916666507720947,
#   0.8833333253860474,
#   0.8916666507720947,
#   0.8916666507720947,
#   0.8833333253860474,
#   0.8916666507720947,
#   0.8999999761581421,
#   0.8916666507720947,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.8999999761581421,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9083333611488342,
#   0.9166666865348816,
#   0.9166666865348816,
#   0.9166666865348816,
#   0.9166666865348816,
#   0.9166666865348816,
#   0.9166666865348816,
#   0.9166666865348816,
#   0.9166666865348816,
#   0.9166666865348816,
#   0.9166666865348816,
#   0.9166666865348816],
#  'val_loss': [1.781013011932373,
#   1.7756695747375488,
#   1.7691243886947632,
#   1.7604457139968872,
#   1.7504068613052368,
#   1.7379183769226074,
#   1.7213023900985718,
#   1.7026952505111694,
#   1.6778465509414673,
#   1.6468454599380493,
#   1.6113905906677246,
#   1.5706952810287476,
#   1.5220413208007812,
#   1.472773790359497,
#   1.4172803163528442,
#   1.3604789972305298,
#   1.3114705085754395,
#   1.2611933946609497,
#   1.223876714706421,
#   1.1869056224822998,
#   1.149204969406128,
#   1.1249620914459229,
#   1.0911649465560913,
#   1.066294550895691,
#   1.0434502363204956,
#   1.0188333988189697,
#   0.9978494048118591,
#   0.9774841070175171,
#   0.9559219479560852,
#   0.9384537935256958,
#   0.9207221269607544,
#   0.9049299955368042,
#   0.888992428779602,
#   0.8739811182022095,
#   0.8591500520706177,
#   0.8446958065032959,
#   0.8308612108230591,
#   0.8178150057792664,
#   0.8058627843856812,
#   0.793158233165741,
#   0.7817507386207581,
#   0.7704060673713684,
#   0.7595860958099365,
#   0.7490264177322388,
#   0.737576425075531,
#   0.7267506718635559,
#   0.7158863544464111,
#   0.7058249115943909,
#   0.6949516534805298,
#   0.6848956346511841,
#   0.6752606630325317,
#   0.6658623814582825,
#   0.6563937067985535,
#   0.6469313502311707,
#   0.6379919052124023,
#   0.6288639307022095,
#   0.6204332113265991,
#   0.6122860312461853,
#   0.6044117212295532,
#   0.5970532894134521,
#   0.5894293189048767,
#   0.5828169584274292,
#   0.5767784118652344,
#   0.5705069303512573,
#   0.5644053220748901,
#   0.5583695769309998,
#   0.5525582432746887,
#   0.5465666651725769,
#   0.540332019329071,
#   0.5344193577766418,
#   0.5283063054084778,
#   0.5229486227035522,
#   0.5173748135566711,
#   0.5119574666023254,
#   0.5061704516410828,
#   0.501257061958313,
#   0.4963222146034241,
#   0.49127161502838135,
#   0.48703962564468384,
#   0.48220425844192505,
#   0.47795432806015015,
#   0.4735625982284546,
#   0.46945446729660034,
#   0.4653826057910919,
#   0.461191862821579,
#   0.4574204087257385,
#   0.45360469818115234,
#   0.4499841630458832,
#   0.44604527950286865,
#   0.44187310338020325,
#   0.4381333589553833,
#   0.434919536113739,
#   0.4319174587726593,
#   0.42822426557540894,
#   0.42557767033576965,
#   0.42122718691825867,
#   0.4193101227283478,
#   0.41583776473999023,
#   0.41280707716941833,
#   0.40954703092575073,
#   0.40690240263938904,
#   0.40368106961250305,
#   0.4008931815624237,
#   0.39834317564964294,
#   0.3953569531440735,
#   0.3921842873096466,
#   0.38967522978782654,
#   0.3870491087436676,
#   0.3842601180076599,
#   0.38157692551612854,
#   0.37921658158302307,
#   0.37678688764572144,
#   0.37422335147857666,
#   0.37246546149253845,
#   0.36950233578681946,
#   0.3672143220901489,
#   0.3646663725376129,
#   0.3627932369709015,
#   0.3605087399482727,
#   0.35838380455970764,
#   0.35650578141212463,
#   0.35397523641586304,
#   0.35276171565055847,
#   0.3497399091720581,
#   0.3478473424911499,
#   0.3458053469657898,
#   0.3433716595172882,
#   0.34169596433639526,
#   0.3388761281967163,
#   0.3377450406551361,
#   0.33510512113571167,
#   0.3337688446044922,
#   0.331680566072464,
#   0.33030250668525696,
#   0.32831621170043945,
#   0.32651254534721375,
#   0.32498735189437866,
#   0.32283467054367065,
#   0.3218362033367157,
#   0.31960251927375793,
#   0.31782981753349304,
#   0.31646302342414856,
#   0.31503283977508545,
#   0.3133172392845154,
#   0.3118351697921753,
#   0.3105107545852661,
#   0.30824244022369385,
#   0.3070829510688782,
#   0.3056240677833557,
#   0.30424442887306213,
#   0.3031589388847351,
#   0.30139055848121643,
#   0.30059120059013367,
#   0.29862987995147705,
#   0.29766908288002014,
#   0.29652610421180725,
#   0.2951461374759674,
#   0.2938727140426636,
#   0.29232022166252136,
#   0.2909267544746399,
#   0.29006195068359375,
#   0.28861674666404724,
#   0.2876998484134674,
#   0.2863740026950836,
#   0.28525975346565247,
#   0.2841796278953552,
#   0.2830561101436615,
#   0.2817969024181366,
#   0.2807941138744354,
#   0.2800520658493042,
#   0.2786014676094055,
#   0.2777113616466522,
#   0.276603639125824,
#   0.2754143476486206,
#   0.2744763195514679,
#   0.27360960841178894,
#   0.27295905351638794,
#   0.27250564098358154,
#   0.2714783847332001,
#   0.27066829800605774,
#   0.2698743939399719,
#   0.2692093849182129,
#   0.2684258818626404,
#   0.267119437456131,
#   0.2668629586696625,
#   0.26586300134658813,
#   0.26445186138153076,
#   0.2642793357372284,
#   0.26340827345848083,
#   0.26239779591560364,
#   0.2616042196750641,
#   0.2609197497367859,
#   0.26043257117271423,
#   0.260114848613739,
#   0.25918230414390564,
#   0.2583584785461426,
#   0.2584831714630127,
#   0.2573797106742859,
#   0.2575014531612396,
#   0.2562868297100067,
#   0.2568102777004242,
#   0.2546418607234955,
#   0.2560499608516693,
#   0.2536456286907196,
#   0.2551869750022888,
#   0.2532884180545807,
#   0.2541327476501465,
#   0.2527559697628021,
#   0.2532309889793396,
#   0.25252872705459595,
#   0.25125542283058167,
#   0.2536509335041046,
#   0.25232914090156555,
#   0.25244027376174927,
#   0.25266972184181213,
#   0.2513390779495239,
#   0.25293034315109253,
#   0.2513352930545807,
#   0.2525225281715393,
#   0.2525196075439453,
#   0.25265824794769287,
#   0.2521800398826599,
#   0.2519504427909851,
#   0.2515791058540344,
#   0.25436389446258545,
#   0.25147852301597595,
#   0.25376006960868835,
#   0.25343677401542664,
#   0.25250428915023804,
#   0.251207172870636,
#   0.25300517678260803,
#   0.2529297173023224,
#   0.2540959417819977,
#   0.25287696719169617,
#   0.25256580114364624,
#   0.2547452747821808,
#   0.25292733311653137,
#   0.2534940838813782,
#   0.25354015827178955,
#   0.2526070773601532,
#   0.25428086519241333,
#   0.25456756353378296,
#   0.25476399064064026,
#   0.2539021670818329,
#   0.25415462255477905,
#   0.2537233531475067,
#   0.25400441884994507,
#   0.25374144315719604,
#   0.253782719373703,
#   0.2543717324733734,
#   0.2541961669921875,
#   0.25515714287757874,
#   0.25365233421325684,
#   0.2538422644138336,
#   0.25388646125793457,
#   0.25409603118896484,
#   0.2535392940044403,
#   0.2537137567996979,
#   0.251895934343338,
#   0.2523384094238281,
#   0.2521946132183075,
#   0.2520737051963806,
#   0.25233936309814453,
#   0.2530467212200165,
#   0.2564481794834137,
#   0.2608686685562134,
#   0.27143800258636475,
#   0.27353546023368835,
#   0.2785743176937103,
#   0.28111550211906433,
#   0.27924248576164246,
#   0.2847961187362671,
#   0.28455984592437744,
#   0.2842184603214264,
#   0.2806451618671417,
#   0.27830711007118225,
#   0.2763744294643402,
#   0.27321872115135193,
#   0.2715700566768646,
#   0.27097827196121216,
#   0.26874950528144836,
#   0.26806360483169556,
#   0.26596373319625854,
#   0.26612821221351624,
#   0.26441994309425354,
#   0.26373419165611267,
#   0.2643622159957886,
#   0.26473790407180786,
#   0.2642125189304352,
#   0.26585400104522705,
#   0.26545238494873047,
#   0.26870912313461304,
#   0.26989951729774475,
#   0.26898106932640076,
#   0.27060651779174805,
#   0.2673768997192383,
#   0.2704113721847534,
#   0.2682580053806305,
#   0.26887163519859314,
#   0.27054911851882935]}

# %% [markdown]
# Now visualize the loss over time using `history.history`:

# %%
# The history.history["loss"] entry is a dictionary with as many values as epochs that the
# model was trained on. 
df_loss_acc = pd.DataFrame(history.history)
df_loss= df_loss_acc[['loss','val_loss']]
df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)
df_acc= df_loss_acc[['accuracy','val_accuracy']]
df_acc.rename(columns={'accuracy':'train','val_accuracy':'validation'},inplace=True)
df_loss.plot(title='Model loss',figsize=(12,8)).set(xlabel='Epoch',ylabel='Loss')
df_acc.plot(title='Model Accuracy',figsize=(12,8)).set(xlabel='Epoch',ylabel='Accuracy')
# Out:
# /usr/lib/python3/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# [Text(0.5, 0, 'Epoch'), Text(0, 0.5, 'Accuracy')]

# %% [markdown]
# **Congratulations**! You've finished the assignment and built two models: One that recognizes  smiles, and another that recognizes SIGN language with almost 80% accuracy on the test set. In addition to that, you now also understand the applications of two Keras APIs: Sequential and Functional. Nicely done!
#
# By now, you know a bit about how the Functional API works and may have glimpsed the possibilities. In your next assignment, you'll really get a feel for its power when you get the opportunity to build a very deep ConvNet, using ResNets!

# %% [markdown]
# <a name='6'></a>
# ## 6 - Bibliography
#
# You're always encouraged to read the official documentation. To that end, you can find the docs for the Sequential and Functional APIs here:
#
# https://www.tensorflow.org/guide/keras/sequential_model
#
# https://www.tensorflow.org/guide/keras/functional
